# %% [markdown]
# ## 1. Lenet 5 Architecture

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# %%
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
x_train = np.pad(x_train, ((0,0),(2,2),(2,2),(0,0)), 'constant')
x_test = np.pad(x_test, ((0,0),(2,2),(2,2),(0,0)), 'constant')

# %%
x_train.shape
# Out:
# (60000, 32, 32, 1)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
import numpy as np

# 1. Load Dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# 2. Preprocessing
# Normalize
x_train = x_train / 255.0
x_test = x_test / 255.0

# Reshape (add channel dimension)
x_train = x_train.reshape(-1, 28, 28, 1) # instead of we fill 60,000 images for batches, -1 says it to pick whatever we have fill it by yourself. In simple words, it is "auto-fill placeholder".
x_test = x_test.reshape(-1, 28, 28, 1)

# Pad to 32x32 (LeNet requirement)
x_train = np.pad(x_train, ((0,0),(2,2),(2,2),(0,0)), 'constant')
x_test = np.pad(x_test, ((0,0),(2,2),(2,2),(0,0)), 'constant')

# One-hot encoding
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# 3. Build LeNet-5 Model
model = models.Sequential()

# C1 - Convolution
model.add(layers.Conv2D(6, kernel_size=(5,5), activation='tanh', input_shape=(32,32,1)))

# S2 - Average Pooling
model.add(layers.AveragePooling2D(pool_size=(2,2)))

# C3 - Convolution
model.add(layers.Conv2D(16, kernel_size=(5,5), activation='tanh'))

# S4 - Average Pooling
model.add(layers.AveragePooling2D(pool_size=(2,2)))

# C5 - Convolution (acts like fully connected)
model.add(layers.Conv2D(120, kernel_size=(5,5), activation='tanh'))

# Flatten
model.add(layers.Flatten())

# F6 - Fully Connected
model.add(layers.Dense(84, activation='tanh'))

# Output Layer
model.add(layers.Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 28, 28, 6)           │             156 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ average_pooling2d_2                  │ (None, 14, 14, 6)           │               0 │
# │ (AveragePooling2D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 10, 10, 16)          │           2,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
# 4. Compile
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 5. Train
model.fit(
    x_train, y_train,
    epochs=10,
    batch_size=64,
    validation_data=(x_test, y_test)
)

# 6. Evaluate
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Accuracy:", test_acc)

# 7. Prediction Example
pred = model.predict(x_test[:5])
print("Predicted:", np.argmax(pred, axis=1))
print("Actual:", np.argmax(y_test[:5], axis=1))
# Out:
# Epoch 1/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.9173 - loss: 0.2763 - val_accuracy: 0.9581 - val_loss: 0.1365
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9693 - loss: 0.1017 - val_accuracy: 0.9732 - val_loss: 0.0871
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9799 - loss: 0.0657 - val_accuracy: 0.9825 - val_loss: 0.0544
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9857 - loss: 0.0472 - val_accuracy: 0.9862 - val_loss: 0.0439
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9879 - loss: 0.0379 - val_accuracy: 0.9859 - val_loss: 0.0446
# Epoch 6/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9911 - loss: 0.0298 - val_accuracy: 0.9852 - val_loss: 0.0455
# Epoch 7/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9919 - loss: 0.0255 - val_accuracy: 0.9856 - val_loss: 0.0441
# Epoch 8/10
# ...

# %% [markdown]
# # THE END
